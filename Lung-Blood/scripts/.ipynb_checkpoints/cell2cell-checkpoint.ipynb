# %%
import pandas as pd
import cell2cell as c2c

# %matplotlib inline

# %% [markdown]
# # Use toy data

# %% [markdown]
# **RNA-seq data**
#
# In this case is a 6x5 matrix (6 genes/proteins and 5 samples/cell types). The values are arbitrary; for simplicity we will use them as TPMs. The indexes of this DataFrame are the names of the genes/proteins, while the columns are the names of samples/cell types.

# %%
blood = pd.read_csv('../../Blood/output_data/Blood_2021-03-01_Step6_meta-analysis.csv', index_col=0,)
#blood = blood.drop(blood.columns[0], axis=1)
#blood =  blood[(blood["qval.random"] < 0.05 ) & (blood["num_exp"] >= 4 ) & (blood["I2"] < .4 )] # DE tresholds
blood =  blood[(blood["qval.random"] < 0.5 ) & (blood["num_exp"] >= 2 ) & (blood["I2"] < .6 )]
blood['blood'] = blood['TE.random']>0
blood['blood'] = blood['blood'].astype(int)
blood
# Out:
#            TE.random   pval.random      tau2        I2    pval.Q  num_exp  \
# X1
# AGPS        0.199160  2.230659e-03  0.012299  0.553591  0.062097        5
# ATP8B2     -0.200317  2.890899e-11  0.000003  0.000000  0.486408        5
# HIVEP2     -0.194406  2.389473e-05  0.003695  0.380706  0.167394        5
# LGALS1      0.136067  2.007181e-05  0.001055  0.225761  0.270650        5
# TSC22D3     0.108554  1.126458e-03  0.002208  0.319135  0.208689        5
# ...              ...           ...       ...       ...       ...      ...
# NDUFAF6    -0.075807  1.183648e-01  0.000000  0.000000  0.373400        2
# KIZ-AS1    -0.046174  1.544199e-01  0.000000  0.000000  0.554005        2
# WHAMMP3    -0.135446  9.390340e-02  0.000000  0.000000  0.560383        2
# SNORA28     0.214547  8.380867e-02  0.000000  0.000000  0.566093        2
# SNORD3B-1  -0.368695  7.304183e-02  0.000000  0.000000  0.430770        2
#
#             qval.random    qval.Q  blood
# X1
# AGPS       3.675400e-02  0.170302      1
# ATP8B2     5.656940e-08  0.619881      0
# HIVEP2     1.414344e-03  0.317433      0
# LGALS1     1.235262e-03  0.428860      1
# TSC22D3    2.249248e-02  0.364537      1
# ...                 ...       ...    ...
# NDUFAF6    4.392635e-01  0.523457      0
# KIZ-AS1    4.959032e-01  0.674009      0
# WHAMMP3    3.893031e-01  0.678877      0
# SNORA28    3.688892e-01  0.682895      1
# SNORD3B-1  3.418963e-01  0.574188      0
#
# [5836 rows x 9 columns]

# %%
lung = pd.read_csv('../../Tissue/output_data/2021-03-01_Step6_meta-analysis.csv', index_col=0)
#lung =  lung[(lung["qval.random"] < 0.05 ) & (lung["num_exp"] >= 9 ) & (lung["I2"] < .4 )] # DE tresholds
lung =  lung[(lung["qval.random"] < 0.5 ) & (lung["num_exp"] >= 5 ) & (lung["I2"] < .6 )]
lung['lung'] = lung['TE.random']>0
lung['lung'] = lung['lung'].astype(int)
lung
# Out:
#          TE.random  pval.random          tau2        I2    pval.Q  num_exp  \
# X1
# TMEM44   -0.168187     0.003076  1.364779e-02  0.577096  0.015311        9
# PAMR1     0.324502     0.000024  2.406830e-02  0.548654  0.023387        9
# DNAJC5B   0.278963     0.000877  3.306975e-02  0.580520  0.014483        9
# SEMA7A    0.130545     0.000677  6.769900e-03  0.516432  0.028705       10
# FTSJ1    -0.167329     0.000313  6.164179e-03  0.485976  0.069684        7
# ...            ...          ...           ...       ...       ...      ...
# MEIS3P1  -0.130058     0.021352  5.668770e-03  0.328750  0.189344        6
# C2CD5    -0.070524     0.028487  2.915312e-08  0.172051  0.305058        5
# ZSCAN31  -0.095489     0.068721  1.641821e-03  0.443798  0.126101        5
# MRGBP    -0.111090     0.023743  4.195561e-03  0.292887  0.226286        5
# USP32P2  -0.132135     0.039886  0.000000e+00  0.000000  0.598835        5
#
#          qval.random    qval.Q  lung
# X1
# TMEM44      0.104569  0.027202     0
# PAMR1       0.004551  0.039393     1
# DNAJC5B     0.048205  0.025900     1
# SEMA7A      0.040710  0.047117     1
# FTSJ1       0.024708  0.102134     0
# ...              ...       ...   ...
# MEIS3P1     0.281506  0.240501     0
# C2CD5       0.320571  0.361234     0
# ZSCAN31     0.464240  0.170264     0
# MRGBP       0.294520  0.280469     0
# USP32P2     0.372978  0.643597     0
#
# [1612 rows x 9 columns]

# %%
both = [blood,lung]
df = pd.concat(both, axis=1)
df = df[['lung','blood']]
df
# Out:
#          lung  blood
# X1
# AGPS      NaN    1.0
# ATP8B2    NaN    0.0
# HIVEP2    NaN    0.0
# LGALS1    NaN    1.0
# TSC22D3   NaN    1.0
# ...       ...    ...
# MEIS3P1   0.0    NaN
# C2CD5     0.0    NaN
# ZSCAN31   0.0    NaN
# MRGBP     0.0    NaN
# USP32P2   0.0    NaN
#
# [7022 rows x 2 columns]

# %% [markdown]
# **Protein-Protein Interactions or Ligand-Receptor Pairs**
#
# In this case, we use a list of LR pairs where some proteins also are ***complexes of multiple subunits***. The complexes are represented as a joint name of ***all subunits*** composing each complex, but ***separated by a separator '&'***. The ligands are in the column 'A', while the receptors in the column 'B'. For these purposes we do not use the column 'score'.
#
# **The names of genes/proteins have to match those in the rnaseq dataset.**

# %%
ppi = pd.read_csv("https://raw.githubusercontent.com/LewisLabUCSD/Ligand-Receptor-Pairs/master/Human/Human-2020-Jin-LR-pairs.csv")

# %%
ppi
# Out:
#          interaction_name pathway_name       ligand       receptor  \
# 0     TGFB1_TGFBR1_TGFBR2         TGFb        TGFB1      TGFbR1_R2
# 1     TGFB2_TGFBR1_TGFBR2         TGFb        TGFB2      TGFbR1_R2
# 2     TGFB3_TGFBR1_TGFBR2         TGFb        TGFB3      TGFbR1_R2
# 3     TGFB1_ACVR1B_TGFBR2         TGFb        TGFB1  ACVR1B_TGFbR2
# 4     TGFB1_ACVR1C_TGFBR2         TGFb        TGFB1  ACVR1C_TGFbR2
# ...                   ...          ...          ...            ...
# 2000            TIGIT_PVR        TIGIT        TIGIT            PVR
# 2001    ITGA4_ITGB1_VCAM1         VCAM  ITGA4_ITGB1          VCAM1
# 2002    ITGA9_ITGB1_VCAM1         VCAM  ITGA9_ITGB1          VCAM1
# 2003    ITGA4_ITGB7_VCAM1         VCAM  ITGA4_ITGB7          VCAM1
# 2004          VSIR_IGSF11        VISTA         VSIR         IGSF11
#
#            agonist       antagonist co_A_receptor             co_I_receptor  \
# 0     TGFb agonist  TGFb antagonist           NaN  TGFb inhibition receptor
# 1     TGFb agonist  TGFb antagonist           NaN  TGFb inhibition receptor
# 2     TGFb agonist  TGFb antagonist           NaN  TGFb inhibition receptor
# 3     TGFb agonist  TGFb antagonist           NaN  TGFb inhibition receptor
# 4     TGFb agonist  TGFb antagonist           NaN  TGFb inhibition receptor
# ...            ...              ...           ...                       ...
# 2000           NaN              NaN           NaN                       NaN
# 2001           NaN              NaN           NaN                       NaN
# 2002           NaN              NaN           NaN                       NaN
# 2003           NaN              NaN           NaN                       NaN
# 2004           NaN              NaN           NaN                       NaN
#
#             evidence          annotation       interaction_name_2  \
# 0     KEGG: hsa04350  Secreted Signaling  TGFB1 - (TGFBR1+TGFBR2)
# 1     KEGG: hsa04350  Secreted Signaling  TGFB2 - (TGFBR1+TGFBR2)
# 2     KEGG: hsa04350  Secreted Signaling  TGFB3 - (TGFBR1+TGFBR2)
# 3     PMID: 27449815  Secreted Signaling  TGFB1 - (ACVR1B+TGFBR2)
# 4     PMID: 27449815  Secreted Signaling  TGFB1 - (ACVR1C+TGFBR2)
# ...              ...                 ...                      ...
# 2000   PMID:24987108   Cell-Cell Contact              TIGIT - PVR
# 2001  KEGG: hsa04514   Cell-Cell Contact    ITGA4 - (ITGB1+VCAM1)
# 2002  KEGG: hsa04514   Cell-Cell Contact    ITGA9 - (ITGB1+VCAM1)
# 2003  KEGG: hsa04514   Cell-Cell Contact    ITGA4 - (ITGB7+VCAM1)
# 2004  KEGG: hsa04514   Cell-Cell Contact            VSIR - IGSF11
#
#      ligand_symbol receptor_symbol                   ligand_ensembl  \
# 0            TGFB1   TGFBR1&TGFBR2                  ENSG00000105329
# 1            TGFB2   TGFBR1&TGFBR2                  ENSG00000092969
# 2            TGFB3   TGFBR1&TGFBR2                  ENSG00000119699
# 3            TGFB1   ACVR1B&TGFBR2                  ENSG00000105329
# 4            TGFB1   ACVR1C&TGFBR2                  ENSG00000105329
# ...            ...             ...                              ...
# 2000         TIGIT             PVR                  ENSG00000181847
# 2001   ITGA4&ITGB1           VCAM1  ENSG00000115232&ENSG00000150093
# 2002   ITGA9&ITGB1           VCAM1  ENSG00000144668&ENSG00000150093
# 2003   ITGA4&ITGB7           VCAM1  ENSG00000115232&ENSG00000139626
# 2004          VSIR          IGSF11                  ENSG00000107738
#
#                      receptor_ensembl   interaction_symbol  \
# 0     ENSG00000106799&ENSG00000163513  TGFB1^TGFBR1&TGFBR2
# 1     ENSG00000106799&ENSG00000163513  TGFB2^TGFBR1&TGFBR2
# 2     ENSG00000106799&ENSG00000163513  TGFB3^TGFBR1&TGFBR2
# 3     ENSG00000135503&ENSG00000163513  TGFB1^ACVR1B&TGFBR2
# 4     ENSG00000123612&ENSG00000163513  TGFB1^ACVR1C&TGFBR2
# ...                               ...                  ...
# 2000                  ENSG00000073008            TIGIT^PVR
# 2001                  ENSG00000162692    ITGA4&ITGB1^VCAM1
# 2002                  ENSG00000162692    ITGA9&ITGB1^VCAM1
# 2003                  ENSG00000162692    ITGA4&ITGB7^VCAM1
# 2004                  ENSG00000144847          VSIR^IGSF11
#
#                                   interaction_ensembl
# 0     ENSG00000105329^ENSG00000106799&ENSG00000163513
# 1     ENSG00000092969^ENSG00000106799&ENSG00000163513
# 2     ENSG00000119699^ENSG00000106799&ENSG00000163513
# 3     ENSG00000105329^ENSG00000135503&ENSG00000163513
# 4     ENSG00000105329^ENSG00000123612&ENSG00000163513
# ...                                               ...
# 2000                  ENSG00000181847^ENSG00000073008
# 2001  ENSG00000115232&ENSG00000150093^ENSG00000162692
# 2002  ENSG00000144668&ENSG00000150093^ENSG00000162692
# 2003  ENSG00000115232&ENSG00000139626^ENSG00000162692
# 2004                  ENSG00000107738^ENSG00000144847
#
# [2005 rows x 17 columns]

# %% [markdown]
# **Metadata**
#
# The metadata contains the extra information for the samples/cell types in the RNA-seq data. This dataframe must contain a column where the samples/cell types are specified (#SampleID) and another with the new information, for example major groups for the samples/cell types (Groups)

# %%
data = [['lung', 'Lung'], ['blood', 'Blood']]
meta =  pd.DataFrame(data, columns = ['#SampleID', 'Groups'])

# %%
meta
# Out:
#   #SampleID Groups
# 0      lung   Lung
# 1     blood  Blood

# %% [markdown]
# # Cell-cell Interactions and Communication Analysis

# %% [markdown]
# **Using an Interaction Pipeline**
#
# The pipeline integrates the RNA-seq and PPI datasets by using the analysis setups. It generates an interaction space containing an instance for each sample/cell type, containing the values assigned to each protein in the PPI list given the setups for computing the CCI and CCC scores.
#
# In this case is for bulk data since the toy data is not for single cell.

# %%
interactions = c2c.analysis.BulkInteractions(rnaseq_data=df,
                                             ppi_data=ppi,
                                             metadata=meta, # Metadata about cells/samples
                                             interaction_columns=('ligand_symbol', 'receptor_symbol'), # PPI columns
                                             complex_sep='&', # For protein complexes
                                             communication_score='expression_product',
                                             expression_threshold=10, # TPMs
                                             cci_score='count',
                                             cci_type='undirected',
                                             sample_col='#SampleID',
                                             group_col='Groups',
                                             verbose=False)

# %%
interactions

# %% [markdown]
# **Compute communication scores for each PPI or LR pair**

# %%
interactions.compute_pairwise_communication_scores()
# Out:
# Computing pairwise communication
# Computing communication score between lung and blood
# Computing communication score between blood and blood
# Computing communication score between blood and lung
# Computing communication score between lung and lung

# %% [markdown]
# **Compute CCI scores for each pair of cells**
#
# It is computed according to the analysis setups. We computed an undirected Bray-Curtis-like score for each pair, meaning that score(C1, C2) = score(C2, C1).
# **Notice that our score is undirected, so for C1 and C2 was not necessary to compute C2 and C1 as happened for the communication scores**

# %%
interactions.compute_pairwise_cci_scores()
# Out:
# Computing pairwise interactions
# Computing interaction score between blood and blood
# Computing interaction score between blood and lung
# Computing interaction score between lung and lung

# %% [markdown]
# # Visualizations
#
# If we want to save the figure as a vector figure, we can pass a pathname into the filename input to save it. E.g. ***filename='/Users/cell2cell/CommScores.svg'***

# %% [markdown]
# **Generate colors for the groups in the metadata**
#
# It returns a dictionary with the colors.

# %%
colors = c2c.plotting.get_colors_from_labels(labels=meta['Groups'].unique().tolist(),
                                             cmap='tab10'
                                            )

# %%
colors = {'Lung': 'darkturquoise', 'Blood': 'firebrick'}
colors
# Out:
# {'Lung': 'darkturquoise', 'Blood': 'firebrick'}

# %% [markdown]
# **Visualize communication scores for each LR pair and each cell pair**

# %%
interaction_clustermap = c2c.plotting.clustermap_ccc(interactions,
                                                     metric='jaccard',
                                                     method='complete',
                                                     metadata=meta,
                                                     sample_col='#SampleID',
                                                     group_col='Groups',
                                                     colors=colors,
                                                     row_fontsize=14,
                                                     title='Active ligand-receptor pairs for interacting cells',
                                                     filename="../fig/CommScores.pdf",
                                                     cell_labels=('SENDER-CELLS', 'RECEIVER-CELLS'),
                                                     **{'figsize' : (10,9)}
                                                     )

# Add a legend to know the groups of the sender and receiver cells:
l1 = c2c.plotting.generate_legend(color_dict=colors,
                                  loc='center left',
                                  bbox_to_anchor=(20, -2), # Indicated where to include it
                                  ncol=1, fancybox=True,
                                  shadow=True,
                                  title='Groups',
                                  fontsize=14,
                                 )
# Out:
# Interaction space detected as a Interactions class

# %% [markdown]
# **Circos plot**
#
# It generates a circos plot, showing the cells producing ligands (sender_cells), according to a list of specific ligands (ligands) to the cells producing receptors (receiver_cells), according to a list of specific receptors (receptors). The order of these lists is preserved in the visualization. Elements that are not used are omitted and therefore not plotted (in this case those with a communication score of 0, specified in 'excluded_score').

# %%
sender_cells = ['lung', 'blood']
receiver_cells = ['lung', 'blood']
ligands = ['LEP',
           'CXCL3',
           'CCL2',
           'CCL7',
           'CXCL2',
           'NMU',
           'NRXN2',
          ]
receptors = ['LEPR',
             'CXCR1',
             'ACKR2',
             'CCR3',
             'CXCR1',
             'NMUR2',
             'NLGN3',
            ]

# %%
c2c.plotting.circos_plot(interaction_space=interactions,
                         sender_cells=sender_cells,
                         receiver_cells=receiver_cells,
                         ligands=ligands,
                         receptors=receptors,
                         excluded_score=0,
                         metadata=meta,
                         sample_col='#SampleID',
                         group_col='Groups',
                         colors=colors,
                         ligand_label_color='purple',
                         receptor_label_color='green',
                         fontsize=15,
                        )

# %% [markdown]
# If we do not pass metadata info, the samples/cell types are only plotted.
#
# We can also change the label colors of ligands and receptors

# %%
c2c.plotting.circos_plot(interaction_space=interactions,
                         sender_cells=sender_cells,
                         receiver_cells=receiver_cells,
                         ligands=ligands,
                         receptors=receptors,
                         excluded_score=0,
                         colors=colors,
                         fontsize=20,
                         ligand_label_color='purple',
                         receptor_label_color='green',
                        )

# %% [markdown]
# **Visualize CCI scores**
#
# Since this case is undirected, a triangular heatmap is plotted instead of the complete one.

# %%
cm = c2c.plotting.clustermap_cci(interactions,
                                 method='complete',
                                 metadata=meta,
                                 sample_col="#SampleID",
                                 group_col="Groups",
                                 colors=colors,
                                 title='CCI scores for cell-types',
                                 cmap='Blues'
                                 )

# Add a legend to know the groups of the sender and receiver cells:
l1 = c2c.plotting.generate_legend(color_dict=colors,
                                  loc='center left',
                                  bbox_to_anchor=(20, -2), # Indicated where to include it
                                  ncol=1, fancybox=True,
                                  shadow=True,
                                  title='Groups',
                                  fontsize=14,
                                 )
# Out:
# Interaction space detected as a Interactions class

# %% [markdown]
# **Project samples/cells with PCoA into a Euclidean space**
#
# We can project the samples/cells given their CCI scores with other cells and see how close they are given their potential of interaction.
#
# **THIS ONLY WORKS WITH UNDIRECTED CCI SCORES**

# %%
if interactions.analysis_setup['cci_type'] == 'undirected':
        
    pcoa = c2c.plotting.pcoa_3dplot(interactions,
                                    metadata=meta,
                                    sample_col="#SampleID",
                                    group_col="Groups",
                                    title='PCoA based on potential CCIs',
                                    colors=colors,
                                    )
# Out:
# Interaction space detected as a Interactions class
